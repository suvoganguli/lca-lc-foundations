# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Cad é is mian leat a dhéanamh inniu? Is féidir liom cabhrú le gach ceann de na rudaí seo a leanas:
#
# - Aistriúcháin idir Gaeilge agus Béarla
# - Míniú gramadaí na Gaeilge agus ceisteanna ar bhriathra, canúint, srl.
# - Scríobh: litir iarratas oibre, CV, nó téacs oibre
# - Samplaí abairtí agus fócas ar scileanna scríbhneoireachta
# - Freagra ar cheisteanna ar ábhair éagsúla (stair, matamaitic, eolaíocht, srl.)
# - Comhairle teanga agus cleachtais ionas go dtuigeann tú agus go húsáidfidh tú an teanga níos fearr
#
# Inis dom cad ba mhaith leat a dhéanamh, agus is tús maith é.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# ¡Hola! ¿En qué puedo ayudarte hoy? Puedo ayudarte a redactar textos, explicar conceptos, resolver problemas de matemáticas o programación, traducir entre idiomas, o estudiar temas. ¿Qué necesitas? Dime y empezamos.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour ! Comment puis-je vous aider aujourd'hui ? Que puis-je faire pour vous : rédaction, traduction, explications techniques, aide à la programmation, conseils, ou autre ? Dites-moi ce dont vous avez besoin et le niveau de détail souhaité.
