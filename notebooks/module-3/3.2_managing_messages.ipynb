# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Summarize messages

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import SummarizationMiddleware

agent = create_agent(
    model="gpt-5-nano",
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("tokens", 100),
            keep=("messages", 1)
        )
    ],
)

# %%
from langchain.messages import HumanMessage, AIMessage
from pprint import pprint

response = agent.invoke(
    {"messages": [
        HumanMessage(content="What is the capital of the moon?"),
        AIMessage(content="The capital of the moon is Lunapolis."),
        HumanMessage(content="What is the weather in Lunapolis?"),
        AIMessage(content="Skies are clear, with a high of 120C and a low of -100C."),
        HumanMessage(content="How many cheese miners live in Lunapolis?"),
        AIMessage(content="There are 100,000 cheese miners living in Lunapolis."),
        HumanMessage(content="Do you think the cheese miners' union will strike?"),
        AIMessage(content="Yes, because they are unhappy with the new president."),
        HumanMessage(content="If you were Lunapolis' new president how would you respond to the cheese miners' union?"),
        ]},
    {"configurable": {"thread_id": "1"}}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="Here is a summary of the conversation to date:\n\nThe capital of the moon is Lunapolis. The weather in Lunapolis has clear skies, with a high of 120C and a low of -100C. There are 100,000 cheese miners living in Lunapolis, and there is a possibility that the cheese miners' union will strike due to discontent with the new president.", additional_kwargs={}, response_metadata={}, id='cbff1b74-0238-45ac-b3cc-482f9c585bd1'),
#               HumanMessage(content="If you were Lunapolis' new president how would you respond to the cheese miners' union?", additional_kwargs={}, response_metadata={}, id='57cf23a8-654b-4754-95c4-4456a9ed8b21'),
#               AIMessage(content='If I were Lunapolis’ new president, I would respond to the cheese miners’ union with an approach that is immediate, fair, and focused on long-term stability. Here’s a practical plan you could adopt or adapt:\n\nCore principles\n- Safety first: mining is dangerous, and climate extremes on the moon make it even more so.\n- Fairness and dignity: workers deserve good wages, benefits, reasonable hours, and respect in negotiations.\n- Transparency: keep miners informed and include them in decision-making where it affects their work.\n- Shared prosperity: align wage and condition improvements with the health of the cheese industry and Lunapolis’ economy.\n\nImmediate actions (first 1–2 weeks)\n- Open dialogue now: announce a direct, good-faith dialogue with union leadership. Appoint a neutral mediator to help structure talks.\n- Safety audit and quick wins: commission an independent safety review of mines and facilities, with rapid fixes prioritized (cooling/heating for extreme temperatures, hydration/rest facilities, proper protective gear, shift management to reduce heat/cold exposure).\n- Protect workers from retaliation: reaffirm protections for union activity, and ensure no punitive measures against workers who voice concerns.\n\nStructured negotiation plan (0–1 month)\n- Create a Joint Negotiation Council: include union reps, company managers, and an independent chair. Agree on a clear agenda: wages, benefits, working conditions, hours, safety, training, and job security.\n- Do the math together: commission a transparent study of cost-of-living on the moon, wage benchmarks for similar dangerous/hard labor, and the budget impact of proposed safety upgrades and benefits.\n- Provisional measures while talks continue: hazard pay during extreme conditions, one-time safety allowances, and agreed-upon rest breaks or shift adjustments to reduce exposure to heat/cold.\n\nWages, benefits, and working conditions (1–3 months)\n- Wage and benefits framework: propose a phased package that rewards performance and recognizes risk. For example, a structured wage increase over 12–24 months, plus hazard pay linked to temperature or risk levels, and enhanced health/retirement benefits.\n- Hours and rest: negotiate caps on maximum daily/weekly hours, mandatory rest periods, and access to climate-controlled rest zones near mines.\n- Safety and training: expand ongoing safety training, certification programs, and cross-training to reduce redundancy and improve career prospects.\n- Job security and retraining: create a plan to minimize layoffs due to automation or process changes, with retraining programs and retriever roles for displaced workers.\n\nLonger-term plan (6–24 months)\n- Investment in the industry: commit to capital improvements that raise productivity while protecting workers (better ventilation, more automatic safety systems, energy-efficient climate control).\n- Climate adaptation: fund and implement robust climate-control infrastructure, emergency drills, and contingency plans for extreme weather events.\n- Governance and accountability: establish quarterly public progress reports on wages, safety stats, training completion, and production targets.\n\nContingencies and strike management\n- If a strike occurs, keep essential operations running safely and transparently, with continuous communication about why certain decisions are being made.\n- Do not use punitive measures; instead, use mediation and, if needed, binding arbitration to resolve core disputes.\n- Preserve cheese supply and public trust: coordinate with supply chain partners to minimize disruption while negotiations continue.\n\nCommunication and success metrics\n- Regular updates: publish minutes or summaries of negotiation meetings, safety audits, and progress toward agreement.\n- Metrics to track: safety incident rate, hours lost to accidents, wage growth relative to cost of living, number of workers trained, and worker satisfaction surv ...

# %%
print(response["messages"][0].content)
# Out:
# Here is a summary of the conversation to date:
#
# The capital of the moon is Lunapolis. The weather in Lunapolis has clear skies, with a high of 120C and a low of -100C. There are 100,000 cheese miners living in Lunapolis, and there is a possibility that the cheese miners' union will strike due to discontent with the new president.

# %% [markdown]
# ## Trim/delete messages

# %%
from typing import Any
from langchain.agents import AgentState
from langchain.messages import RemoveMessage
from langgraph.runtime import Runtime
from langchain.agents.middleware import before_agent
from langchain.messages import ToolMessage

@before_agent
def trim_messages(state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
    """Remove all the tool messages from the state"""
    messages = state["messages"]

    tool_messages = [m for m in messages if isinstance(m, ToolMessage)]
    
    return {"messages": [RemoveMessage(id=m.id) for m in tool_messages]}

# %%
agent = create_agent(
    model="gpt-5-nano",
    checkpointer=InMemorySaver(),
    middleware=[trim_messages],
)

# %%
response = agent.invoke(
    {"messages": [
        HumanMessage(content="My device won't turn on. What should I do?"),
        ToolMessage(content="blorp-x7 initiating diagnostic ping…", tool_call_id="1"),
        AIMessage(content="Is the device plugged in and turned on?"),
        HumanMessage(content="Yes, it's plugged in and turned on."),
        ToolMessage(content="temp=42C voltage=2.9v … greeble complete.", tool_call_id="2"),
        AIMessage(content="Is the device showing any lights or indicators?"),
        HumanMessage(content="What's the temperature of the device?")
        ]},
    {"configurable": {"thread_id": "2"}}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="My device won't turn on. What should I do?", additional_kwargs={}, response_metadata={}, id='8b385708-f9ab-4ff5-bf57-9aeaa4e8c4f3'),
#               AIMessage(content='Is the device plugged in and turned on?', additional_kwargs={}, response_metadata={}, id='8b924ec8-7b99-4312-996d-833859d0feaf'),
#               HumanMessage(content="Yes, it's plugged in and turned on.", additional_kwargs={}, response_metadata={}, id='f6b1b7f2-ad10-4eb3-b87d-661ab5e2593d'),
#               AIMessage(content='Is the device showing any lights or indicators?', additional_kwargs={}, response_metadata={}, id='afd34537-6d73-4484-8501-35d83ddcd144'),
#               HumanMessage(content="What's the temperature of the device?", additional_kwargs={}, response_metadata={}, id='d3e1907a-b3a1-48a8-84f0-cd55b9da498e'),
#               AIMessage(content='I can’t read your device’s temperature from here. If you want to check it yourself, here are options by device type. Let me know your exact device (brand/model/OS) and I can tailor the steps.\n\n- Computers\n  - Windows: Use a tool like HWMonitor, Core Temp, or Open Hardware Monitor. Check CPU/GPU temps. Idle CPU ~30–50°C; under load 60–85°C is typical. If you see temps above ~90°C, shut down and inspect cooling (fans, vents, dust, thermal paste).\n  - macOS: Use a third‑party app like iStat Menus or Macs Fan Control to monitor temps. You can also run powermetrics in Terminal for a quick read. Typical temps vary, but don’t let sensors stay very high for long.\n  - Linux: Install lm-sensors and run sensors to see CPU/GPU temps.\n\n- Smartphones\n  - Android: Some devices show battery/CPU temperature in Settings (Battery) or use a third‑party app (CPU-Z, HWMonitor). Battery temps above ~45–50°C while charging indicate overheating.\n  - iPhone: iOS doesn’t always expose temps, but if it’s hot, close apps, remove case, avoid charging in heat, and let it cool. Third‑party apps exist but may be limited.\n\n- Other devices (routers, etc.)\n  - Many don’t show a temperature readout; rely on indicators or web/admin pages if available. If it’s hot and there’s smell or buzzing, power down and ventilate.\n\nImmediate safety tips if it’s very hot\n- If you smell burning or see smoke, power off, unplug, and move to a safe area.\n- Let it cool in a ventilated spot for 15–30 minutes before attempting to power on again.\n- Check vents, fans, and ensure vents aren’t blocked. Clean dust if you’re comfortable doing so.\n\nIf you share the device type, model, and what you’re seeing (any indicators, fan noise, etc.), I’ll give you precise steps to check the temperature and interpret the readings.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1980, 'prompt_tokens': 71, 'total_tokens': 2051, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1536, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CqGlBcjCcxUqhuMVfuYgqIPLsjzfW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4ffc-a8cc-7931-8b00-f253e0b9e4be-0', usage_metadata={'input_tokens': 71, 'output_tokens': 1980, 'total_tokens': 2051, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1536}})]}

# %%
print(response["messages"][-1].content)
# Out:
# I can’t read your device’s temperature from here. If you want to check it yourself, here are options by device type. Let me know your exact device (brand/model/OS) and I can tailor the steps.
#
# - Computers
#   - Windows: Use a tool like HWMonitor, Core Temp, or Open Hardware Monitor. Check CPU/GPU temps. Idle CPU ~30–50°C; under load 60–85°C is typical. If you see temps above ~90°C, shut down and inspect cooling (fans, vents, dust, thermal paste).
#   - macOS: Use a third‑party app like iStat Menus or Macs Fan Control to monitor temps. You can also run powermetrics in Terminal for a quick read. Typical temps vary, but don’t let sensors stay very high for long.
#   - Linux: Install lm-sensors and run sensors to see CPU/GPU temps.
#
# - Smartphones
#   - Android: Some devices show battery/CPU temperature in Settings (Battery) or use a third‑party app (CPU-Z, HWMonitor). Battery temps above ~45–50°C while charging indicate overheating.
#   - iPhone: iOS doesn’t always expose temps, but if it’s hot, close apps, remove case, avoid charging in heat, and let it cool. Third‑party apps exist but may be limited.
#
# - Other devices (routers, etc.)
#   - Many don’t show a temperature readout; rely on indicators or web/admin pages if available. If it’s hot and there’s smell or buzzing, power down and ventilate.
#
# Immediate safety tips if it’s very hot
# - If you smell burning or see smoke, power off, unplug, and move to a safe area.
# - Let it cool in a ventilated spot for 15–30 minutes before attempting to power on again.
# - Check vents, fans, and ensure vents aren’t blocked. Clean dust if you’re comfortable doing so.
#
# If you share the device type, model, and what you’re seeing (any indicators, fan noise, etc.), I’ll give you precise steps to check the temperature and interpret the readings.
