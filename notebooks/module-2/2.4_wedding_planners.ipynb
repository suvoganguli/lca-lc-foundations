# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. Delegate tasks to your specialists for flights, venues and playlists.
    First find all the information you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='0e075f67-5557-4b80-81f6-dedba7c17be8'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 485, 'prompt_tokens': 293, 'total_tokens': 778, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2e56JNvX8vUOYM7JDdCytwnPNZt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4cc0-c976-7903-a9bc-9a9bf9bb2174-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_NajyPL1f9IivUsta6iMoTmMX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 485, 'total_tokens': 778, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='af879af1-9ec1-4b73-adbc-e4bfe6368a1f', tool_call_id='call_NajyPL1f9IivUsta6iMoTmMX'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 254, 'prompt_tokens': 338, 'total_tokens': 592, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2eAB4DExuo1rqJZ4ikmzro98IgB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4cc0-dc7a-7e01-9837-afc48ebdc1ad-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_4Wiq8eA2Hem8n4PY3Eb45OO3', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_MiztbKWdQa8J99bWZy1Rcw6R', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_5ZV9QmHbNen33CvgpVB9rxsD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 338, 'output_tokens': 254, 'total_tokens': 592, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Here are the best one-way flight options from London to Paris, organized by price (lowest first), then shortest duration, with a few notable alternatives for variety. All options are one-way.\n\nCheapest options (price: 49 EUR)\n- Flight: LTN → CDG (direct)\n  - Dates/Times (local): 01/06/2026, 19:40 → 22:00\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 49 EUR\n  - Book: https://on.kiwi.com/EvQ6Fn\n\n- Flight: LTN → CDG (direct)\n  - Dates/Times (local): 15/06/2026, 19:40 → 22:00\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 49 EUR\n  - Book: https://on.kiwi.com/EvQ6Fn\n\nShortest duration options (duration: 4200 seconds, i.e., 1h 10m)\n- Flight: STN → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 17:00 → 19:10\n  - Duration: 4200 seconds (1h 10m)\n  - Cabin: Economy\n  - Price: 65 EUR\n  - Book: https://on.kiwi.com/CXowBV\n\n- Flight: SEN → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 11:20 → 13:30\n  - Duration: 4200 seconds (1h 10m)\n  - Cabin: Economy\n  - Price: 102 EUR\n  - Book: https://on.kiwi.com/eKZdYA\n\nOther notable options (by price, remaining good choices)\n- Flight: LTN → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 16:20 → 18:40\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 105 EUR\n  - Book: https://on.kiwi.com/SM6Sjm\n\n- Flight: LTN → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 19:00 → 21:20\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 105 EUR\n  - Book: https://on.kiwi.com/97Xvl9\n\n- Flight: LGW → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 18:00 → 20:20\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 110 EUR\n  - Book: https://on.kiwi.com/2GTOOS\n\n- Flight: LGW → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 16:30 → 18:50\n  - Duration: 4800 seconds (1h 20m)\n  - Cabin: Economy\n  - Price: 110 EUR\n  - Book: https://on.kiwi.com/kh4isj\n\n- Flight: LHR → CDG (direct)\n  - Dates/Times (local): 15/05/2026, 08:40 → 16:00\n  - Duration: 22800 seconds (6h 20m)\n  - Cabin: Economy\n  - Price: 121 EUR\n  - Book: https://on.kiwi.com/lFkdPV\n\nRecommendation\n- Best value (lowest price): LTN → CDG on 01/06/2026 or 15/06/2026 for 49 EUR, direct, economy. Book via the provided deep links.\n- Quickest option among the cheapest: STN → CDG on 15/05/2026 for 65 EUR, direct, economy (1h 10m).\n\nFun fact and a quick tip\n- Fun fact: Paris is known as the City of Light (La Ville Lumière) and is famed for its iconic cafes, bakeries, and cuisine—perfect for a wedding trip where you can celebrate with croissants and macarons after your ceremony.\n- Travel tip: If you’re considering alternatives, the Eurostar high-speed train from London to Paris typically takes about 2h 15m and can be a delightful daytime option when schedules align.\n\nIf you’d like, I can narrow to a specific date range (or a single date) and present a tighter shortlist focused on that window. Have a wonderful trip planning your wedding journey!', name='search_flights', id='39396b63-9a53-44dc-b262-21a71faa538b', tool_call_id='call_4Wiq8eA2Hem8n4PY3Eb45OO3'),
#               ToolMessage(content='Here are Paris wedding venues that can accommodate around 100 guests, prioritizing lower price where known and venues with strong capacity alignment (100 exact or clearly up to 100). I’ve included why they’re a good pick and where to check details.\n\n- Les 3 Salons (Saint-Germain-des-Prés, Paris)\n  - Capacity: up to 100 guests (range often cited as 30–100)\n  - Price: from about €900 (venue hire, depending on configuration)\n  - Why it’s a fit: intimate, historic trio of vaulted spaces in a central Paris location; flexible layouts for cocktails, dinner, and dancing\n  - Source: Les 3 Salons capacity; price info available via listing pages\n  - Link: https://www.les3salons.net/blank-c1tmc (capacity page) and related listing pages\n\n- The Peninsula Paris (Arc de Triomphe area)\n  - Capacity: can host up to 100 guests for a sit-down dinner\n  - Price: premium/luxury level (exact quotes on request)\n  - Why it’s a fit: iconic luxury hotel with a dedicated wedding team, elegant ballrooms, and top-tier service\n  - Source: Peninsula Paris wedding spaces page\n  - Link: https://www.peninsula.com/en/paris/events/hotel-wedding-venues\n\n- Hotel Marignan Champs-Elysées (Champs-Élysées area)\n  - Capacity: up to 100 guests for cocktails and aperitifs (80 for a sit-down meal)\n  - Price: premium (high-end venue)\n  - Why it’s a fit: chic Haussmannian setting near the Champs-Élysées, with intimate spaces and excellent service\n  - Source: Hotel Marignan wedding venues page\n  - Link: https://www.hotelmarignanelyseesparis.com/en/pagex/wedding-venues-paris-france.285.html\n\n- Rooftop des Champs-Élysées (Les Champs-Élysées area)\n  - Capacity: up to 100 guests for cocktails (venue configurations vary; some spaces list 50–150 total capacity)\n  - Price: premium (rooftop venue)\n  - Why it’s a fit: stunning city views, flexible outdoor/indoor layout, ideal for a stylish 100-guest celebration\n  - Source: Rooftop Paris venue pages\n  - Link: https://rooftop-paris.com/fr/location-rooftop/rooftop-des-champs-elysees/\n\nNotes\n- All of these options can accommodate around 100 guests, with several offering exact 100-capacity configurations for either cocktail receptions or seated dinners.\n- Pricing for luxury venues in Paris is typically on request and varies by date, inclusions (catering, staffing, décor), and guest count. The Les 3 Salons option is the most price-accessible among the explicitly-cited options, while The Peninsula Paris and Hotel Marignan Champs-Elysées are premium choices.\n- If you’d like, I can pull additional options that consistently list 100 as an exact capacity and provide current price quotes and review rankings.', name='search_venues', id='1f1b2e5f-19b9-4beb-b038-e7e66baf085e', tool_call_id='call_MiztbKWdQa8J99bWZy1Rcw6R'),
#               ToolMessage(content="Here’s a curated jazz wedding playlist pulled from the Jazz results. It blends Brazilian bossa nova vibes with smooth classic jazz for a romantic, dance-friendly vibe. Total duration is about 56 minutes and 46 seconds, and the total cost is $19.80 (20 tracks at $0.99 each).\n\n1) Outra Vez — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:06 — Price: $0.99\n2) Fotografia — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:09 — Price: $0.99\n3) Lament — Miles Davis — Album: Miles Ahead — Duration: 2:14 — Price: $0.99\n4) Se Todos Fossem Iguais A Você (Instrumental) — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:15 — Price: $0.99\n5) Samba De Uma Nota Só (One Note Samba) — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:17 — Price: $0.99\n6) Coronation Drop — Gene Krupa — Album: Up An' Atom — Duration: 2:56 — Price: $0.99\n7) The Meaning Of The Blues — Miles Davis — Album: Miles Ahead — Duration: 2:49 — Price: $0.99\n8) Generique — Miles Davis — Album: The Essential Miles Davis [Disc 1] — Duration: 2:49 — Price: $0.99\n9) Angela — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:50 — Price: $0.99\n10) Por Causa De Você — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:50 — Price: $0.99\n11) Disc Jockey Jump — Gene Krupa — Album: Up An' Atom — Duration: 3:13 — Price: $0.99\n12) Leave Us Leap — Gene Krupa — Album: Up An' Atom — Duration: 3:03 — Price: $0.99\n13) Desafinado — Antonio Carlos Jobim — Album: Warner 25 Anos — Duration: 3:05 — Price: $0.99\n14) Jeepers Creepers — Gene Krupa — Album: Up An' Atom — Duration: 3:07 — Price: $0.99\n15) Let Me Off Uptown — Gene Krupa — Album: Up An' Atom — Duration: 3:08 — Price: $0.99\n16) Bop Boogie — Gene Krupa — Album: Up An' Atom — Duration: 3:10 — Price: $0.99\n17) Swedish Schnapps — Gene Krupa — Album: Up An' Atom — Duration: 3:11 — Price: $0.99\n18) I Don't Wanna Be Kissed (By Anyone But You) — Miles Davis — Album: Miles Ahead — Duration: 3:11 — Price: $0.99\n19) Drum Boogie — Gene Krupa — Album: Up An' Atom — Duration: 3:12 — Price: $0.99\n20) I Don't Wanna Be Kissed (By Anyone But You) (Alternate Take) — Miles Davis — Album: Miles Ahead — Duration: 3:12 — Price: $0.99\n\nTotal duration: approximately 56 minutes 46 seconds\nTotal cost: $19.80\n\nNotes and tips:\n- This mix emphasizes warm, romantic vibes suitable for cocktail hour and dinner, with a few more upbeat tracks to keep energy flowing for dancing.\n- If you’d like a shorter set (e.g., 30–40 minutes) I can trim to 10–12 tracks focusing on the Jobim/Bossa Nova side.\n- If you’d prefer more vocal standards or a different tempo balance, I can swap in additional Miles Davis, Spyro Gyra, or Incognito selections from the results. Want me to tailor the list to a specific portion of the event (e.g., just cocktail hour or just dinner)?", name='suggest_playlist', id='625b4f96-491b-4307-ba6f-70261f09ca3c', tool_call_id='call_5ZV9QmHbNen33CvgpVB9rxsD'),
#               AIMessage(content='Fantastic! I’ve lined up the essentials for a 100-guest Paris wedding with a jazz vibe. Here’s a concise briefing of what we’ve gathered and what I suggest next.\n\nWhat we’ve secured so far\n- Flights (for guests traveling London → Paris)\n  - Best value: London Luton to Paris CDG, direct, about 49 EUR\n    - Dates: 01/06/2026 19:40–22:00 or 15/06/2026 19:40–22:00\n    - Link for booking: provided\n  - Quickest affordable option: London Stansted to CDG, direct, about 65 EUR\n    - Date: 15/05/2026 17:00–19:10\n    - Link for booking: provided\n  - Other good options: LGW or LHR to CDG with 110–121 EUR range; most direct options are 1h20m or longer if involving LHR timings\n  - Note: Eurostar is a lovely daytime option London → Paris (about 2h15m) if timings fit\n- Venues in Paris for around 100 guests\n  - Les 3 Salons (Saint-Germain-des-Prés)\n    - Capacity: up to 100\n    - Price: from about €900 (venue hire; varies by configuration)\n    - Why it fits: intimate, historic, central; flexible layouts\n    - Link: capacity page and listings\n  - The Peninsula Paris (Arc de Triomphe area)\n    - Capacity: up to 100 for a sit-down dinner\n    - Price: premium; quotes on request\n    - Why it fits: iconic luxury, dedicated wedding team, superb service\n    - Link: wedding spaces page\n  - Hotel Marignan Champs-Élysées (Champs-Élysées)\n    - Capacity: up to 100 for cocktails (80 for a seated dinner)\n    - Price: premium\n    - Why it fits: chic Haussmannian, intimate spaces, excellent service\n    - Link: wedding venues page\n  - Rooftop des Champs-Élysées (Champs-Élysées area)\n    - Capacity: up to 100 for cocktails; some spaces list 50–150 total\n    - Price: premium\n    - Why it fits: stunning city views, flexible indoor/outdoor layout\n    - Link: rooftop venue page\n- Jazz playlist concept\n  - A curated mix blending bossa nova with classic jazz for a romantic, dance-friendly vibe\n  - Tracks include Jobim, Miles Davis, Gene Krupa, and more\n  - Duration: ~56 minutes 46 seconds; cost around $19.80 for 20 tracks\n  - Note: I can tailor to more vocal standards, deeper swing, or keep it strictly instrumental—your call\n  - Playlist details and sample tracks were shared\n\nProposed plan to coordinate (next steps)\n1) Lock a date window\n   - Do you have a preferred month(s) or a date range for the ceremony and reception? Even a rough window helps me secure the best venue options and flight blocks.\n2) Select a venue (shortlist)\n   - Which option best fits your vibe and budget?\n     - Les 3 Salons: most price-accessible of the Paris options listed\n     - The Peninsula Paris: premium luxury, spectacular for a wow moment\n     - Hotel Marignan Champs-Elysées: chic and intimate, strong service\n     - Rooftop des Champs-Élysées: stunning views, great for a stylish outdoor/indoor mix\n   - I can request updated quotes and availability for your preferred date window and hold tentative options.\n3) Plan guest travel\n   - Do you want me to propose a single or few flight options to present to guests?\n   - Would you like a group-block approach (discounted rates, set dates) or individual guest booking guidance?\n   - Any preferred London airports for the block (LON area options: LTN, STN, LGW, LHR, LCY) or Paris arrivals (CDG vs ORY)?\n4) Entertainment and music\n   - Do you want:\n     - A live jazz quartet/dusion for cocktail hour and dinner, plus a DJ for dancing after dinner, or\n     - A DJ-led set with curated jazz-leaning tracks (using the playlist as a base)?\n   - I can source 2–3 ensemble options with quotes and set a meeting to discuss song lists, first-dance music, and a dance-floor plan.\n5) Catering and décor\n   - Any dietary restrictions or guest preferences I should anticipate?\n   - Do you want any specific décor themes to pair with the jazz vibe (e.g., Art Deco, Parisian chic, garden-romance)?\n6) Accommodation block\n   - Should I start lining up a few partner hotels for guest r ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic! I’ve lined up the essentials for a 100-guest Paris wedding with a jazz vibe. Here’s a concise briefing of what we’ve gathered and what I suggest next.
#
# What we’ve secured so far
# - Flights (for guests traveling London → Paris)
#   - Best value: London Luton to Paris CDG, direct, about 49 EUR
#     - Dates: 01/06/2026 19:40–22:00 or 15/06/2026 19:40–22:00
#     - Link for booking: provided
#   - Quickest affordable option: London Stansted to CDG, direct, about 65 EUR
#     - Date: 15/05/2026 17:00–19:10
#     - Link for booking: provided
#   - Other good options: LGW or LHR to CDG with 110–121 EUR range; most direct options are 1h20m or longer if involving LHR timings
#   - Note: Eurostar is a lovely daytime option London → Paris (about 2h15m) if timings fit
# - Venues in Paris for around 100 guests
#   - Les 3 Salons (Saint-Germain-des-Prés)
#     - Capacity: up to 100
#     - Price: from about €900 (venue hire; varies by configuration)
#     - Why it fits: intimate, historic, central; flexible layouts
#     - Link: capacity page and listings
#   - The Peninsula Paris (Arc de Triomphe area)
#     - Capacity: up to 100 for a sit-down dinner
#     - Price: premium; quotes on request
#     - Why it fits: iconic luxury, dedicated wedding team, superb service
#     - Link: wedding spaces page
#   - Hotel Marignan Champs-Élysées (Champs-Élysées)
#     - Capacity: up to 100 for cocktails (80 for a seated dinner)
#     - Price: premium
#     - Why it fits: chic Haussmannian, intimate spaces, excellent service
#     - Link: wedding venues page
#   - Rooftop des Champs-Élysées (Champs-Élysées area)
#     - Capacity: up to 100 for cocktails; some spaces list 50–150 total
#     - Price: premium
#     - Why it fits: stunning city views, flexible indoor/outdoor layout
#     - Link: rooftop venue page
# - Jazz playlist concept
#   - A curated mix blending bossa nova with classic jazz for a romantic, dance-friendly vibe
#   - Tracks include Jobim, Miles Davis, Gene Krupa, and more
#   - Duration: ~56 minutes 46 seconds; cost around $19.80 for 20 tracks
#   - Note: I can tailor to more vocal standards, deeper swing, or keep it strictly instrumental—your call
#   - Playlist details and sample tracks were shared
#
# Proposed plan to coordinate (next steps)
# 1) Lock a date window
#    - Do you have a preferred month(s) or a date range for the ceremony and reception? Even a rough window helps me secure the best venue options and flight blocks.
# 2) Select a venue (shortlist)
#    - Which option best fits your vibe and budget?
#      - Les 3 Salons: most price-accessible of the Paris options listed
#      - The Peninsula Paris: premium luxury, spectacular for a wow moment
#      - Hotel Marignan Champs-Elysées: chic and intimate, strong service
#      - Rooftop des Champs-Élysées: stunning views, great for a stylish outdoor/indoor mix
#    - I can request updated quotes and availability for your preferred date window and hold tentative options.
# 3) Plan guest travel
#    - Do you want me to propose a single or few flight options to present to guests?
#    - Would you like a group-block approach (discounted rates, set dates) or individual guest booking guidance?
#    - Any preferred London airports for the block (LON area options: LTN, STN, LGW, LHR, LCY) or Paris arrivals (CDG vs ORY)?
# 4) Entertainment and music
#    - Do you want:
#      - A live jazz quartet/dusion for cocktail hour and dinner, plus a DJ for dancing after dinner, or
#      - A DJ-led set with curated jazz-leaning tracks (using the playlist as a base)?
#    - I can source 2–3 ensemble options with quotes and set a meeting to discuss song lists, first-dance music, and a dance-floor plan.
# 5) Catering and décor
#    - Any dietary restrictions or guest preferences I should anticipate?
#    - Do you want any specific décor themes to pair with the jazz vibe (e.g., Art Deco, Parisian chic, garden-romance)?
# 6) Accommodation block
#    - Should I start lining up a few partner hotels for guest rooms at preferred price points near the venue?
#
# What I can do right away for you
# - Narrow the flight options to a two-date window you approve, then present a compact, guest-friendly block of flight options with group booking details.
# - Reach out to the top two venue choices for availability, exact capacity confirmation, and preliminary quotes on your date window.
# - Draft a 2–3 hour jazz-focused wedding playlist with optional live-ensemble or DJ integration notes, plus a timeline for cocktail hour, dinner, and dancing.
# - Prepare a rough budget outline (venue + catering + entertainment + flights + accommodations) to help you see where adjustments may be needed.
#
# Questions for you
# - Do you have a preferred date window (month/year or a rough weekend)?
# - Which venue option aligns best with your vision: classic Parisian intimate (Les 3 Salons), luxury landmark (The Peninsula), chic Haussmannian (Hotel Marignan), or rooftop with city views?
# - How would you like to handle guest travel: group block vs individual bookings? Any preferred London departure airports?
# - Do you want live jazz or a high-quality jazz-focused DJ, or a combination?
# - Any must-haves for the ceremony or reception (live ceremony musician, first-dance song, special entrances)?
#
# If you share your date window and your top venue pick (or if you want I can proceed to actively inquire about availability and quotes for all four), I’ll start locking in holds, drafting contracts, and coordinating with vendors. Ready when you are.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
