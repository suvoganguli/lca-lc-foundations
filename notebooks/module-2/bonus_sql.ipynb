# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='8d184c88-d02c-47ef-8940-c64547fcb81c'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 666, 'prompt_tokens': 142, 'total_tokens': 808, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2pAY5N7I7uevewqfTf20ElIKVw6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4ccb-41d8-7be2-b50a-f4481a344d1b-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'SHOW TABLES;'}, 'id': 'call_9hH8SjZBH7FHvr783Pxyngd5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 142, 'output_tokens': 666, 'total_tokens': 808, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  ToolMessage(content='Error: (sqlite3.OperationalError) near "SHOW": syntax error\n[SQL: SHOW TABLES;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)', name='sql_query', id='34e55ddb-d13f-4a3f-809f-35c6a3ecbc93', tool_call_id='call_9hH8SjZBH7FHvr783Pxyngd5'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 288, 'prompt_tokens': 218, 'total_tokens': 506, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2pIuJUFhFuRo6mFnbE0GGfE948y', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4ccb-6170-7163-9cdc-2c639e5a6ea6-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table';"}, 'id': 'call_DTqxGSTku6XQ10F7lanZjSBw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 288, 'total_tokens': 506, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='e2bfd5c5-bdc9-4b42-8d70-6837212ae080', tool_call_id='call_DTqxGSTku6XQ10F7lanZjSBw'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 303, 'total_tokens': 330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2pLPp09rflt0uctwmAEqYjK043P', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4ccb-6e88-7ad2-88b5-076792154b11-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT Name FROM Artist WHERE Name LIKE 'S%';"}, 'id': 'call_HZGMPGc3jEaGo61mxOXiy4RR', 'type': 'tool_call'}], usage_metadata={'input_tokens': 303, 'output_tokens': 27, 'total_tokens': 330, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[('Sandra De Sá',), ('Spyro Gyra',), ('Santana',), ('Santana Feat. Dave Matthews',), ('Santana Feat. Everlast',), ('Santana Feat. Rob Thomas',), ('Santana Feat. Lauryn Hill & Cee-Lo',), ('Santana Feat. The Project G&B',), ('Santana Feat. Maná',), ('Santana Feat. Eagle-Eye Cherry',), ('Santana Feat. Eric Clapton',), ('Simply Red',), ('Skank',), ('Smashing Pumpkins',), ('Soundgarden',), ('Stevie Ray Vaughan & Double Trouble',), ('Stone Temple Pilots',), ('System Of A Down',), ('Snow Patrol',), ('Scorpions',), ('Seu Jorge',), ('Sabotage E Instituto',), ('Stereo Maracana',), ('Scholars Baroque Ensemble',), ('Sir Georg Solti & Wiener Philharmoniker',), ('Sergei Prokofiev & Yuri Temirkanov',), ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker',)]", name='sql_query', id='e212c497-55b5-4cce-b45e-94dfdd66c4d9', tool_call_id='call_HZGMPGc3jEaGo61mxOXiy4RR'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 679, 'prompt_tokens': 580, 'total_tokens': 1259, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2pM4CDZLQnI3kdMhnNBqDwbOKp1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4ccb-72ef-7ae2-b993-599508883212-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT a.Name, SUM(il.Quantity) AS TotalSold\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nWHERE a.Name LIKE 'S%'\nGROUP BY a.Name\nORDER BY TotalSold DESC\nLIMIT 1;"}, 'id': 'call_Q68GFtYnB9ABMLQnqsYVEvRe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 580, 'output_tokens': 679, 'total_tokens': 1259, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  ToolMessage(content="[('Smashing Pumpkins', 24)]", name='sql_query', id='1bdbb11f-ae1c-49a8-ab04-81952661272c', tool_call_id='call_Q68GFtYnB9ABMLQnqsYVEvRe'),
#  AIMessage(content="The most popular artist whose name starts with 'S' is Smashing Pumpkins.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 698, 'total_tokens': 718, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq2pSB0yAKk4cx0Zwmo16AqYwBZHi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4ccb-8a49-7120-8d51-1be0d95ff91e-0', usage_metadata={'input_tokens': 698, 'output_tokens': 20, 'total_tokens': 718, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
print(response["messages"][-3].tool_calls[0]['args']['query'])
# Out:
# SELECT a.Name, SUM(il.Quantity) AS TotalSold
# FROM Artist a
# JOIN Album al ON al.ArtistId = a.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# JOIN InvoiceLine il ON il.TrackId = t.TrackId
# WHERE a.Name LIKE 'S%'
# GROUP BY a.Name
# ORDER BY TotalSold DESC
# LIMIT 1;
