# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='542aa7e6-905d-4396-bc3b-95c4b9369f34'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 914, 'prompt_tokens': 1229, 'total_tokens': 2143, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpuiRCprexIzp6OkbSCPDMIL8lqQc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4aef-a639-75a0-b2a6-2a9b9ff6beca-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'EUR', 'locale': 'en'}, 'id': 'call_X9aBfVto0v0oaQAiEgHDZdsj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1229, 'output_tokens': 914, 'total_tokens': 2143, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T23:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T11:00:00.000Z",\n      "local": "2026-04-01T20:00:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n    "durationInSeconds": 40500,\n    "price": 291,\n    "deepLink": "https://on.kiwi.com/IuuDCM",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T01:36:00.000Z",\n      "local": "2026-03-31T18:36:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T07:25:00.000Z",\n      "local": "2026-04-02T16:25:00.000"\n    },\n    "totalDurationInSeconds": 107340,\n    "durationInSeconds": 107340,\n    "price": 367,\n    "deepLink": "https://on.kiwi.com/fFhRS5",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HNL",\n        "city": "Honolulu",\n        "cityCode": "HNL",\n        "arrival": {\n          "utc": "2026-04-01T07:23:00.000Z",\n          "local": "2026-03-31T21:23:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T22:40:00.000Z",\n          "local": "2026-04-01T12:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:10:00.000Z",\n      "local": "2026-03-31T09:10:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T13:30:00.000Z",\n      "local": "2026-04-01T22:30:00.000"\n    },\n    "totalDurationInSeconds": 76800,\n    "durationInSeconds": 76800,\n    "price": 409,\n    "deepLink": "https://on.kiwi.com/n1wRPz",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HNL",\n        "city": "Honolulu",\n        "cityCode": "HNL",\n        "arrival": {\n          "utc": "2026-03-31T21:48:00.000Z",\n          "local": "2026-03-31T11:48:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:10:00.000Z",\n          "local": "2026-03-31T14:10:00.000"\n        }\n      },\n      {\n        "at": "GUM",\n        "city": "Hagåtña",\n        "cityCode": "GUM",\n        "arrival": {\n          "utc": "2026-04-01T08:05:00.000Z",\n          "local": "2026-04-01T18:05:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T09:30:00.000Z",\n          "local": "2026-04-01T19:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:10:00.000Z",\n      "local": "2026-03-31T09:10:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T10:55:00.000Z",\n      "local": "2026-04-02T19:55:00.000"\n    },\n    "totalDurationInSeconds": 153900,\n    "durationInSeconds": 153900,\n    "price": 411,\n    "deepLink": "https://on.kiwi.com/DBDa1D",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HNL",\n        "city": "Honolulu",\n        "cityCode": "HNL",\n        "arrival": {\n          "utc": "2026-03-31T21:48:00.000Z",\n          "local": "2026-03-31T11:48:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:10:00.000Z",\n          "local": "2026-03-31T14:10:00.000"\n        }\n      },\n      {\n        "at": "GUM",\n        "city": "Hagåtña",\n        "cityCode": "GUM",\n        "arrival": {\n          "utc": "2026-04-01T08:05:00.000Z",\n          "local": "2026-04-01T18:05:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T06:55:00.000Z",\n          "local": "2026-04-02T16:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure ...
#               AIMessage(content='Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026. I’ve grouped them by price (cheapest first) and then by duration.\n\nCheapest\n- Flight 1\n  - Route: SFO → NRT\n  - Schedule: 31/03 16:45 → 01/04 20:00 (11h 15m)\n  - Cabin: M\n  - Price: 291 EUR\n  - Booking: https://on.kiwi.com/IuuDCM\n\nShortest (11h 15m)\n- Flight 2\n  - Route: SFO → NRT\n  - Schedule: 31/03 18:40 → 01/04 14:55 (11h 15m)\n  - Cabin: M\n  - Price: 610 EUR\n  - Booking: https://on.kiwi.com/P4YhZo\n- Flight 3\n  - Route: SFO → NRT\n  - Schedule: 31/03 18:40 → 01/04 14:55 (11h 15m)\n  - Cabin: M\n  - Price: 633 EUR\n  - Booking: https://on.kiwi.com/CR5B6X\n\nRest\n- No additional direct options beyond the three listed above.\n\nSummary\n- Best price: 291 EUR (direct)\n- Shortest flights: 11h 15m (the two 18:40 departures at 610 EUR and 633 EUR)\n- Recommendation: If you want the lowest price, go with Flight 1 (291 EUR). If you prefer a departure later in the day with the same duration, Flights 2 or 3 are good alternatives.\n- Fun fact about Tokyo: Tokyo is famous for its food scene, including a high concentration of Michelin-starred restaurants—the city has long been one of the top-ranked places in the world for fine dining.\n\nHave a fantastic trip! Tokyo awaits with blend of ultra-modern sights and traditional experiences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9658, 'prompt_tokens': 5867, 'total_tokens': 15525, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 9216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpuicBRZSWPUBkbvL9ikWqCpayYjZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4aef-d364-7f12-9064-89220db06428-0', usage_metadata={'input_tokens': 5867, 'output_tokens': 9658, 'total_tokens': 15525, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 9216}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026. I’ve grouped them by price (cheapest first) and then by duration.
#
# Cheapest
# - Flight 1
#   - Route: SFO → NRT
#   - Schedule: 31/03 16:45 → 01/04 20:00 (11h 15m)
#   - Cabin: M
#   - Price: 291 EUR
#   - Booking: https://on.kiwi.com/IuuDCM
#
# Shortest (11h 15m)
# - Flight 2
#   - Route: SFO → NRT
#   - Schedule: 31/03 18:40 → 01/04 14:55 (11h 15m)
#   - Cabin: M
#   - Price: 610 EUR
#   - Booking: https://on.kiwi.com/P4YhZo
# - Flight 3
#   - Route: SFO → NRT
#   - Schedule: 31/03 18:40 → 01/04 14:55 (11h 15m)
#   - Cabin: M
#   - Price: 633 EUR
#   - Booking: https://on.kiwi.com/CR5B6X
#
# Rest
# - No additional direct options beyond the three listed above.
#
# Summary
# - Best price: 291 EUR (direct)
# - Shortest flights: 11h 15m (the two 18:40 departures at 610 EUR and 633 EUR)
# - Recommendation: If you want the lowest price, go with Flight 1 (291 EUR). If you prefer a departure later in the day with the same duration, Flights 2 or 3 are good alternatives.
# - Fun fact about Tokyo: Tokyo is famous for its food scene, including a high concentration of Michelin-starred restaurants—the city has long been one of the top-ranked places in the world for fine dining.
#
# Have a fantastic trip! Tokyo awaits with blend of ultra-modern sights and traditional experiences.
