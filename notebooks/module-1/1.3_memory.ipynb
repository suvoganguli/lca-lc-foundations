# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='bd915385-4bfa-43cd-a68a-994a6f9c95cc'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calm and nature-inspired. How can I help today? Do you want to chat about something in particular, practice English, or get information on a topic you like?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 441, 'prompt_tokens': 18, 'total_tokens': 459, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpB8NldCFAicIL3iWN1NCT7huUiu5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b407e-0f2e-7702-87ff-6efbd396a022-0', usage_metadata={'input_tokens': 18, 'output_tokens': 441, 'total_tokens': 459, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f69036ba-4c4d-417e-ae6a-f6f90dbfce32'),
#               AIMessage(content='I don’t know your favorite color yet. If you want, I can guess or help you figure it out.\n\nMy quick guess: blue. It’s a very common favorite.\n\nIf you’d like to pinpoint it, answer a few quick questions:\n- Do you prefer cool tones (blue/green/purple) or warm tones (red/orange/yellow)?\n- Do you like bright/vibrant colors or muted pastels?\n- Do you tend to wear darker shades or lighter ones?\n- Do you want something that blends with most outfits or something that really stands out?\n\nOr tell me three colors you like and I’ll pick the best one for you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1038, 'prompt_tokens': 11, 'total_tokens': 1049, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpB8cBxPBB94J4JIqY7FAMm8TX1kz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b407e-4c6a-7d11-a166-134baf76ee15-0', usage_metadata={'input_tokens': 11, 'output_tokens': 1038, 'total_tokens': 1049, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8da598bb-664b-4426-98bb-70e7d8dea9e2'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—do you have a favourite shade or a green thing you love? If you’d like, we can chat about green color ideas, gardening, or anything else you’re curious about.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 571, 'prompt_tokens': 18, 'total_tokens': 589, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpB8wAxWxlFCG6WPGrxnvPKxLAjLB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b407e-995a-7f60-9586-eef4b1ecafdb-0', usage_metadata={'input_tokens': 18, 'output_tokens': 571, 'total_tokens': 589, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='8da598bb-664b-4426-98bb-70e7d8dea9e2'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—do you have a favourite shade or a green thing you love? If you’d like, we can chat about green color ideas, gardening, or anything else you’re curious about.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 571, 'prompt_tokens': 18, 'total_tokens': 589, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpB8wAxWxlFCG6WPGrxnvPKxLAjLB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b407e-995a-7f60-9586-eef4b1ecafdb-0', usage_metadata={'input_tokens': 18, 'output_tokens': 571, 'total_tokens': 589, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='004e4671-83ff-4941-a3ff-81bf7716e16c'),
#               AIMessage(content='Your favourite colour is green. Would you like to talk about green shades, plants and gardening, or something else related to green?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 291, 'prompt_tokens': 83, 'total_tokens': 374, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpB9GOp5OLI84VcWfM6yjUcN9ZNsT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b407e-ebbc-7ee3-a0f6-e4eb51290c72-0', usage_metadata={'input_tokens': 83, 'output_tokens': 291, 'total_tokens': 374, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}
