# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice are a great combo. Here are some tasty options I found that use those two ingredients:
#
# - Chicken Fried Rice (one-pan)
#   - What it is: Quick, weeknight-friendly stir-fry using leftover chicken and rice with soy sauce and green onions.
#   - Why you’ll like it: Fast, customizable, and a great way to use up leftovers in one skillet.
#   - Source: https://quickweeknightmeals.com/chicken-fried-rice/
#
# - Leftover Chicken and Egg Fried Rice
#   - What it is: Fried rice with leftover chicken and eggs; a simple, family-friendly version that’s great for using up leftovers.
#   - Why you’ll like it: Very quick and flexible; you can add veggies if you have them.
#   - Source: https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/
#
# - Chicken and Rice Casserole
#   - What it is: A creamy, baked casserole that starts from leftover chicken and rice, usually with peas, cheese, and a condensed soup base.
#   - Why you’ll like it: Cozy, hands-off bake; comfy weeknight option.
#   - Source: https://www.crazyforcrust.com/chicken-and-rice-casserole/
#
# If you’d like, I can pull the full recipe steps for any of these and tailor them to what you have on hand (e.g., swap in any veggies or spices you’ve got). Tell me which one you want the full instructions for, or share what other ingredients you have (vegetables, eggs, cheese, sauces), and I’ll customize a plan.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='78749ab5-29a8-4ade-ab2b-31792e5a269b'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 476, 'prompt_tokens': 199, 'total_tokens': 675, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpC2WsqtE7QaGOwnEkKk27pydz0P1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b40b3-306a-7ef0-9f57-a0ce7c881db5-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes using leftover chicken and rice'}, 'id': 'call_WqL3jVwBSaRHwZrRfXIbW5wm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 199, 'output_tokens': 476, 'total_tokens': 675, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='{"query": "recipes using leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/843066235833642/posts/3044839922322918/", "title": "What are some meal ideas using chicken breast and leftover rice?", "content": "Leftover chicken breast, frozen veggies and \\"5 minute rice.\\" Boiled veggies Rice with water, butter, salt and pepper for 5 minutes in the", "score": 0.90330297, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "# Chicken Fried Rice *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.* You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. ## How To Make Chicken Fried Rice * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice Use leftover chicken and rice to make this easy one pan dinner. 5. Add rice, chicken, and soy sauce.", "score": 0.88372874, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Home | Recipe Index | Savory | Casserole | Chicken and Rice Casserole. # Chicken and Rice Casserole. This is the best chicken and rice recipe because it’s easy to make with simple ingredients that you can switch up depending on your tastes. It’s what I consider a “leftover” recipe because I use leftover chicken and rice to make it. ## Ingredients for Chicken and Rice Casserole. ## How to make Chicken and Rice Casserole. For my chicken and rice casserole you will want to use cooked chicken. ## Chicken and Rice Casserole. Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! Easy Chicken and Rice Casserole is a cheesy, creamy baked casserole with condensed soup, peas and chicken. ### Chicken and Rice Casserole. 1. The chicken and rice casserole was very easy to make and my family is asking me to make it as a daily dinner they loved so much.", "score": 0.8747745, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14500 subscribers\\n48 likes\\n7728 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.8638634, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice** *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8616433, "raw_content": null}], "response_time": 0.52, "request_id": "3d382f0c-ef76-4f16-99c6-7d61d57e9ebd"}', name='web_search', id='5b07b92e-a77e-4405-9350-ff8a9ecd368a', tool_call_id='call_WqL3jVwBSaRHwZrRfXIbW5wm'),
#               AIMessage(content='Nice! Leftover chicken and rice are a great combo. Here are some tasty options I found that use those two ingredients:\n\n- Chicken Fried Rice (one-pan)\n  - What it is: Quick, weeknight-friendly stir-fry using leftover chicken and rice with soy sauce and green onions.\n  - Why you’ll like it: Fast, customizable, and a great way to use up leftovers in one skillet.\n  - Source: https://quickweeknightmeals.com/chicken-fried-rice/\n\n- Leftover Chicken and Egg Fried Rice\n  - What it is: Fried rice with leftover chicken and eggs; a simple, family-friendly version that’s great for using up leftovers.\n  - Why you’ll like it: Very quick and flexible; you can add veggies if you have them.\n  - Source: https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/\n\n- Chicken and Rice Casserole\n  - What it is: A creamy, baked casserole that starts from leftover chicken and rice, usually with peas, cheese, and a condensed soup base.\n  - Why you’ll like it: Cozy, hands-off bake; comfy weeknight option.\n  - Source: https://www.crazyforcrust.com/chicken-and-rice-casserole/\n\nIf you’d like, I can pull the full recipe steps for any of these and tailor them to what you have on hand (e.g., swap in any veggies or spices you’ve got). Tell me which one you want the full instructions for, or share what other ingredients you have (vegetables, eggs, cheese, sauces), and I’ll customize a plan.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1823, 'prompt_tokens': 1192, 'total_tokens': 3015, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1472, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpC2cTLbOaCHqFgR6qGBRKG4xSWsN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b40b3-4771-7ef1-94d4-7e6e8e047c9c-0', usage_metadata={'input_tokens': 1192, 'output_tokens': 1823, 'total_tokens': 3015, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1472}})]}
