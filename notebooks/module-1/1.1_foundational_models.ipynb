# %%
from dotenv import load_dotenv

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government, so it has no capital city.\n\nIf you’re thinking in fiction or worldbuilding, people often invent a capital name. Some ideas:\n- Lunapolis\n- Selene City\n- Luna Capital\n- Crater City\n- Moonport (a port capital, if you want a trade focus)\n\nIf you want, tell me the vibe (hard sci-fi, noir, whimsical, etc.) and I can tailor a few options with quick backstories.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 815, 'prompt_tokens': 13, 'total_tokens': 828, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cou6r7HBW9dwVhf6ZY7psJ1zxJvBC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b3c97-803c-7091-90e1-d83e2f77b61c-0', usage_metadata={'input_tokens': 13, 'output_tokens': 815, 'total_tokens': 828, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government, so it has no capital city.
#
# If you’re thinking in fiction or worldbuilding, people often invent a capital name. Some ideas:
# - Lunapolis
# - Selene City
# - Luna Capital
# - Crater City
# - Moonport (a port capital, if you want a trade focus)
#
# If you want, tell me the vibe (hard sci-fi, noir, whimsical, etc.) and I can tailor a few options with quick backstories.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Cou6r7HBW9dwVhf6ZY7psJ1zxJvBC',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 815,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 704,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 828}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or cities, so there’s no capital. If humans someday establish a governed settlement on the Moon, they might designate a capital, but for now there isn’t one. (Also, the Outer Space Treaty prohibits national claims of sovereignty over the Moon.)
#
# Want to know about current lunar missions or ideas for future Moon bases?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent settlements or government.
#
# If you're asking about potential future lunar bases, there are currently no permanent human settlements on the Moon, though several countries and private companies are planning future lunar missions and possible bases.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# model = ChatGoogleGenerativeAI(model="gemini-3-pro-preview")
model = ChatGoogleGenerativeAI(model="gemini-flash-latest")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question!
#
# Currently, the Moon is not a country or a self-governing entity, so it doesn't have an official political capital city.
#
# However, if we're talking about **human activity** on the Moon, we could look at the most famous historical landing site:
#
# * **Tranquility Base** (where Apollo 11 landed) is arguably the "historical capital" or most recognized place name on the Moon.
#
# In the future, as NASA, ESA, China, and private companies plan for permanent lunar bases (like the **Artemis Program's Moon Base Camp**), one of those settlements would eventually take on the role of the primary hub or "capital" of human lunar operations!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b23d7650-fe09-4a91-a92b-1d55417839c1'),
#               AIMessage(content='There isn’t one. The Moon has no government or capital city. It’s a natural satellite with no political jurisdiction. (In fiction, authors sometimes invent imaginary capitals, but none exist in reality.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 433, 'prompt_tokens': 13, 'total_tokens': 446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CouCdxMrBeECiaRWTLdMY7H3BQciu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b3c9c-f665-7400-ba02-e771cb90c5d8-0', usage_metadata={'input_tokens': 13, 'output_tokens': 433, 'total_tokens': 446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or capital city. It’s a natural satellite with no political jurisdiction. (In fiction, authors sometimes invent imaginary capitals, but none exist in reality.)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='fafa41a9-766d-48de-8557-63ebedd59776'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2825b4a7-027a-4d0e-8d9d-38fc822e5192'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='44ff4055-e522-4598-8bd2-01e70ea7286b'),
#               AIMessage(content='Since Luna City is fictional, here’s a richly imagined version you can use for a story, game, or world-building.\n\nOverview\n- Luna City is the administrative and cultural capital of the Moon, located near the Shackleton crater rim to maximize access to water ice while staying within shielded, inhabited zones. It’s the political center of the Moon Commonwealth (a loose federation of lunar settlements) and the hub for commerce, research, and cross-planetary diplomacy.\n\nKey districts and landmarks\n- Core Dome District: the political heart with government buildings, courts, and the central archives. Sunlight is harvested via reflective canopies, and interiors use smart glass that tints automatically.\n- Port Aurora: the main spaceport and logistics hub where cargo from Earth and other colonies arrives. An outer ring hosts repair yards, launch prep, and passenger terminals.\n- Helix Platform: a vertical city district built inside a rotating ring to simulate mild artificial gravity for long-term residents and to house laboratories in a gravity-controlled environment.\n- Waterworks Crescent: the residential and industrial zone anchored by ice-mining facilities, oxygen production plants, and hydroponic farms supplying fresh produce to the city.\n- Mare Library and Culture Quarters: museums, theaters, virtual-reality studios, and GIS-enabled archives that preserve lunar history, science, and art.\n- Lunar Greenbelt: a ring of parks and bio-domes that use recycled water and soil-free agriculture to provide a calm buffer against dust and radiation.\n\nTechnology and infrastructure\n- Energy: giant solar arrays on the lunar far side feed a central power hub, with excess stored in advanced battery banks and regolith-based heat storage.\n- Habitat and life support: closed-loop life support, water reclamation, and regolith shielding. Many domes are inflatable or 3D-printed and then reinforced with regolith bricks.\n- Mobility: an integrated lunar transport network includes maglev shuttles between districts, rover corridors for surface travel, and tethered elevator systems at the rim for quick access to the surface.\n- Communications: a deep-space communications hub links Luna City to Earth and other colonies, supported by relay satellites in high lunar orbit.\n\nSociety and governance\n- Government: a Lunar City Council governs Luna City, with representatives from major districts and citizen-assembled committees. A rotating mayoral office handles daily administration, while policy is shaped by longer-term lunar accords and Earth-aided research partnerships.\n- Law and order: a civil code adapted for lunar life emphasizes habitat autonomy, resource sharing, and environmental stewardship. Dissent and civil dialogue are encouraged through public forums and holo-debates.\n- Education and culture: schools emphasize STEM, habitat design, and lunar history. Culture flourishes through art, music, and festivals that celebrate Earth-Moon ties and lunar exploration milestones.\n- Daily life: residents live in family- or community-dwelling clusters, with public spaces designed for low-gravity activity, leisure in microgravity gyms, and abundant access to education and healthcare.\n\nEconomy and daily life\n- Economy: driven by water ice extraction, life-support manufacturing, satellite and rover fabrication, biotech research in closed ecosystems, and a growing tourism and research-seminar sector.\n- Jobs: engineers, hydroponics managers, habitat designers, scientists, educators, and craft artisans who create lunar-grade glassware, textiles, and art from lunar materials.\n- Food and health: meals rely on hydroponics produce, lab-cultured proteins, and hydro-processed grains. Medical facilities emphasize telepresence care, rapid diagnostics, and radiation shielding clinics.\n\nCulture and lifestyle\n- Identity: residents often blend Earth roots with lunar experience, creating a culture that prioritizes resilience, col ...

# %%
content = response['messages'][-1].content
if isinstance(content, list):
    content = "\n".join(str(x) for x in content)
print(content)
# Out:
# Since Luna City is fictional, here’s a richly imagined version you can use for a story, game, or world-building.
#
# Overview
# - Luna City is the administrative and cultural capital of the Moon, located near the Shackleton crater rim to maximize access to water ice while staying within shielded, inhabited zones. It’s the political center of the Moon Commonwealth (a loose federation of lunar settlements) and the hub for commerce, research, and cross-planetary diplomacy.
#
# Key districts and landmarks
# - Core Dome District: the political heart with government buildings, courts, and the central archives. Sunlight is harvested via reflective canopies, and interiors use smart glass that tints automatically.
# - Port Aurora: the main spaceport and logistics hub where cargo from Earth and other colonies arrives. An outer ring hosts repair yards, launch prep, and passenger terminals.
# - Helix Platform: a vertical city district built inside a rotating ring to simulate mild artificial gravity for long-term residents and to house laboratories in a gravity-controlled environment.
# - Waterworks Crescent: the residential and industrial zone anchored by ice-mining facilities, oxygen production plants, and hydroponic farms supplying fresh produce to the city.
# - Mare Library and Culture Quarters: museums, theaters, virtual-reality studios, and GIS-enabled archives that preserve lunar history, science, and art.
# - Lunar Greenbelt: a ring of parks and bio-domes that use recycled water and soil-free agriculture to provide a calm buffer against dust and radiation.
#
# Technology and infrastructure
# - Energy: giant solar arrays on the lunar far side feed a central power hub, with excess stored in advanced battery banks and regolith-based heat storage.
# - Habitat and life support: closed-loop life support, water reclamation, and regolith shielding. Many domes are inflatable or 3D-printed and then reinforced with regolith bricks.
# - Mobility: an integrated lunar transport network includes maglev shuttles between districts, rover corridors for surface travel, and tethered elevator systems at the rim for quick access to the surface.
# - Communications: a deep-space communications hub links Luna City to Earth and other colonies, supported by relay satellites in high lunar orbit.
#
# Society and governance
# - Government: a Lunar City Council governs Luna City, with representatives from major districts and citizen-assembled committees. A rotating mayoral office handles daily administration, while policy is shaped by longer-term lunar accords and Earth-aided research partnerships.
# - Law and order: a civil code adapted for lunar life emphasizes habitat autonomy, resource sharing, and environmental stewardship. Dissent and civil dialogue are encouraged through public forums and holo-debates.
# - Education and culture: schools emphasize STEM, habitat design, and lunar history. Culture flourishes through art, music, and festivals that celebrate Earth-Moon ties and lunar exploration milestones.
# - Daily life: residents live in family- or community-dwelling clusters, with public spaces designed for low-gravity activity, leisure in microgravity gyms, and abundant access to education and healthcare.
#
# Economy and daily life
# - Economy: driven by water ice extraction, life-support manufacturing, satellite and rover fabrication, biotech research in closed ecosystems, and a growing tourism and research-seminar sector.
# - Jobs: engineers, hydroponics managers, habitat designers, scientists, educators, and craft artisans who create lunar-grade glassware, textiles, and art from lunar materials.
# - Food and health: meals rely on hydroponics produce, lab-cultured proteins, and hydro-processed grains. Medical facilities emphasize telepresence care, rapid diagnostics, and radiation shielding clinics.
#
# Culture and lifestyle
# - Identity: residents often blend Earth roots with lunar experience, creating a culture that prioritizes resilience, collaboration, and curiosity.
# - Festivals: Apolune Night (a festival celebrating a rare two-sun turnout with light installations), Solstice Market (a lunar commerce fair), and Archive Day (public exhibits of lunar discovery).
# - Art and science fusion: public science demos, light-based sculpture, and interactive holo-memories of lunar missions are common.
#
# Challenges and tensions (for drama or realism)
# - Resource balance: ensuring a steady water/air supply while expanding habitats and preserving radiation shielding.
# - Isolation: long-term mental health and community cohesion in a closed habitat can be a theme; education and cultural exchange programs help.
# - Earth dependence: periodic supply chain lags or political shifts on Earth can impact Luna City’s plans.
# - Dust and radiation: continuous protection required, with occasional failures prompting rapid engineering responses.
# - Governance puzzles: debates over autonomy vs. federal oversight, land rights within the Moon Commonwealth, and interplanetary diplomacy.
#
# Story seeds and character ideas
# - A planetary diplomat negotiates resource-sharing terms between Luna City and a rival lunar outpost.
# - A young engineer uncovers a fault in the regolith shielding that could jeopardize an entire district.
# - An archivist at Mare Library discovers a hidden, centuries-old Earth artifact that challenges lunar-origin myths.
# - A schoolteacher pilots a citizen-science project that maps micro-meteoroid impacts on the Core Dome.
# - A festival organizer curates an interplanetary art-forward celebration that uses solar light as a medium.
#
# If you want, I can tailor Luna City to a specific genre (hard SF, space opera, dystopian, utopian), era (near-term, mid-century, far-future), or create a sample scene, map concepts, or a character roster. What vibe or format are you aiming for?

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional, speculative capital built for the Moon. There is no real Luna City today, but it’s a rich setup you can use for science fiction, worldbuilding, games, or creative writing. Below is a cohesive concept you can adopt as-is or adapt to your preferred tone (hard SF, cyberpunk, utopian, dystopian, etc.).
#
# Core concept
# - Luna City is the political, scientific, and cultural hub of a multinational lunar polity. It sits at the edge of a permanently shadowed, water-ice-containing crater in the Moon’s south polar region, chosen for access to local resources and near-constant solar energy on the crater rim. It functions as the de facto capital of the Moon and hosts the Inter-Lunar Council, major research institutes, corporate HQs, and the cultural heartbeat of lunar civilization.
#
# Quick facts
# - Location: South polar region, near Shackleton Crater (a representative choice; feel free to relocate to another polar crater or a large crater rim to suit your story).
# - Population: A few hundred thousand residents (within domed habitats and interconnected tunnels and tubes).
# - Government: A representative lunar federation with a central governing council (the Inter-Lunar Council) and a Luna City Assembly. Local governance runs through a City Council and sector ministries.
# - Economy: Water/oxygen production and storage, in-situ resource utilization (ISRU) for propellants, construction materials from regolith, solar energy, robotics and AI services, lunar tourism, and high-end research funding from Earth-based partners.
# - Major institutions: Inter-Lunar Council, Luna City Assembly, Lunar Research Syndicate, Orbital Transfer Authority, Solar Power Grid Directorate, Ice Hall (water management), and the Lunar Museum of HumanIngenuity.
# - Notable features: A central spire/clocktower, a network of pressurized tunnels, a ring of solar farms around the crater rim, multiple geodesic domes for living and research, a public transit hub, and a protected ice storage facility.
#
# Geography and environment
# - Topography: A large crater rim forms the city’s spine, with terraces and artificial sunlit floors. The interior of the crater hosts hydroponic farms, oxygen production, and ISRU plants. The rim shelves are lined with glass and polymer domes connected by tunnel corridors.
# - Climate and life support: No atmosphere; natural radiation and micrometeoroids are constant hazards. Life support relies on closed-loop systems, power from solar arrays, and deposits of lunar ice for water and oxygen.
# - Energy: Primary energy from a large ring of solar farms on crater rim petals, supplemented by compact modular reactors for night-side demand. Heat management is done via regolith shielding and thermal loops.
# - Transport corridors: Surface mag-rail segments and heavy-duty lunar rovers, plus an extensive tunnel network beneath the domes and along the crater floor.
#
# History and lore
# - Founding narrative: Initial human outposts in the late 21st/early 22nd century; by the mid-22nd century, a multinational treaty led to a centralized lunar government. Luna City rose as the capital after proving it could efficiently integrate water extraction, energy production, and governance.
# - Key milestones:
#   - The Ice Accord (agreement to share water resources from the crater ice deposits).
#   - The Spire Accession, a ceremonial moment when the central spire became the symbol of lunar unity.
#   - The Great Interchange, a transit and data-sharing hub that connected lunar settlements to Earth orbit and Earth-based cities.
#   - The 4th Season Crisis, a radiation surge and supply chain disruption that accelerated autonomous robotics and ISRU capabilities.
#
# Political structure
# - The Inter-Lunar Council (ILC): A representative body where lunar settlements, research stations, and corporate lunar subsidiaries appoint delegates. Jurisdiction covers resource management, security protocols, and inter-settlement treaties.
# - Luna City Assembly: A directly elected body within Luna City that handles urban policy, housing, education, culture, and local law.
# - Ministries and agencies:
#   - Ministry of Resources (water, oxygen, ISRU materials)
#   - Ministry of Energy and Infrastructure (power grids, tunnels, domes)
#   - Ministry of Science and Education (universities, labs, outreach)
#   - Ministry of Culture and Heritage (museums, arts, lunar festivals)
#   - Lunar Security Directorate (public safety, space weather monitoring, civil defense)
# - Law and rights: A charter guarantees basic rights, including freedom of movement between lunar districts, access to education, and protections for workers and researchers. AI and autonomous systems are legal agents with defined rights and responsibilities in civil life.
#
# Economy
# - Core sectors:
#   - ISRU and resource processing (water ice, oxygen, regolith-derived materials)
#   - Energy production and storage (solar, with modular reactors)
#   - Construction and manufacturing (3D-printed habitat modules, tooling from regolith)
#   - Research and development (astrophysics, planetary science, life support tech)
#   - Tourism and culture (guided tours of domed districts, ice caves, and the lunar night markets)
# - Currency and trade: Luna Credits (LC) circulate in lunar and Earth-lunar markets, with pricing tied to Earth-based currencies and resource exchange rates.
# - Trade partners: Earth-based corporations, space agencies, and other lunar settlements. The city negotiates favorable terms for resource sharing and transit rights.
#
# Society and culture
# - Demographics: A diverse mix of scientists, engineers, artists, teachers, technicians, and support staff. Multilingual, with Lunar Standard (LS) as lingua franca alongside Earth languages.
# - Education: Strong emphasis on STEM, life support design, environmental ethics, and arts. Universities and internship programs partner with Earth institutions.
# - Arts and leisure: The Cultural Quarter hosts lunar cinema, holographic museums, music halls, and a Space Garden—an indoor bio-dome with flora from Earth and lunar-adapted botanicals.
# - Daily life: Residents live in modular domes or interconnected apartment clusters. Community governance emphasizes participatory budgeting for local projects (playgrounds, art installations, climate-control upgrades).
# - Religion and philosophy: A secular civic culture with a spectrum of beliefs; some communities incorporate lunar cycles as rituals or seasonal festivals.
#
# Infrastructure and technology
# - Housing and domes: A mix of pressurized transparent domes for living, agriculture, and research. Habitats are modular, expandable, and shielded with regolith or inflatable cores.
# - Water and life support: Ice deposits are melted, purified, and stored in secure facilities. Oxygen is generated via electrolysis and algae-based scrubbing in closed-loop systems.
# - Transportation:
#   - Surface vehicles: electric rovers and cargo haulers adapted for powdery regolith.
#   - Underground tunnels: safety-protected transit lines with air circulation, radiation shielding, and rapid-repair robots.
#   - Transit hubs: A central hub links surface routes to Earth-Moon transfer corridors and orbital stations.
# - Research and industry labs: Cleanrooms for microgravity experiments, biotech, materials science, and in-situ manufacturing (3D printing from lunar regolith and recycled plastics).
# - Security and resilience: Radiation monitoring, dust mitigation systems, redundant power and water networks, and emergency shelters connected by shielded corridors.
#
# Districts and landmarks
# - Government Quarter: The executive offices, council chambers, and judicial facilities. Ceremonial plazas and the Central Spire, a beacon of lunar unity.
# - Science Quarter: Major research institutes, astronomical observatories, AI labs, and a large particle/space physics facility.
# - Industrial Dockyards: Material processing, regolith conversion plants, construction materials, and logistics hubs for import/export.
# - Residential Sectors: Clusters of domes named for lunar explorers or poets; common areas include markets, schools, and clinics.
# - Cultural Quarter: Museums, theaters, libraries, performance spaces, and lunar festivals.
# - Waterworks and Agriculture: Ice storage, water treatment plants, hydroponic farms, and labs for soil-less agriculture experiments.
# - Transit and Connectivity Hub: The central transport spine, with mag-rail links to other lunar settlements and ferry lanes to orbital stations.
#
# Notable features and icons
# - The Central Spire: A tall, illuminated tower that doubles as a time signal and observatory.
# - Ice Hall: A fortress-like ice storage facility that protects lunar water reserves from solar flux and micrometeorite impacts.
# - The Glass Ring: A translucent ring around part of the crater rim that acts as a solar concentration field and a public promenade.
# - The Moon Museum of Human Ingenuity: A repository of lunar exploration artifacts, art, and patient histories from long-term habitation trials.
#
# Security and defense
# - Public safety is a priority due to the harsh environment. Defense is primarily civil and civil-safety oriented, focusing on infrastructure protection, cyber-security, and cosmic-ray monitoring.
# - Contingencies include long-term power outages, dust storms, solar storms, and supply-chain disruptions. Redundant life-support and autonomous repair fleets keep essential services online.
#
# What a day in Luna City might look like
# - Morning: Residents wake in a domed residential cluster. Hydroponic farms light up with a spectrum tuned for optimal plant growth. A research team in the Science Quarter prepares a microgravity experiment for a space-weather window.
# - Midday: The Assembly holds a session in the Government Quarter. Delegates discuss water-sharing terms with a nearby orbital outpost and Earth-based partners. Food trucks in the Cultural Quarter offer Earth-inspired dishes adapted to lunar growing conditions.
# - Evening: A public transit ride along the rim promenade provides spectacular views of Earth and the terminator line. A concert at the Lunar Cultural Hall ends with a projection of the lunar surface that feels almost close enough to touch.
# - Night: Security and maintenance platforms run continuous diagnostics; researchers monitor ice stability to prevent a loss-of-cuel water reserve; the central spire pulses with light to indicate power stability.
#
# Variant tones you can adopt
# - Hard SF: A technically detailed, pragmatic, and sometimes austere Luna City focusing on resource management, engineering challenges, and interplanetary politics.
# - Utopian: Emphasis on harmony, citizen governance, rapid innovation, and a transparent, inclusive society with advanced welfare systems.
# - Cyberpunk: Corporate control, noir aesthetics, private security outfits, street markets in the Cultural Quarter, and a clash between public good and private interests.
# - Space Opera: Grand-scale politics, interstellar alliances, dramatic festivals, and heroic figures ferrying between Luna City and the rest of the system.
#
# Story seeds and prompts
# - A water shortage triggers a crisis; a detective/public official uncovers a covert ISRU plant deliberately polluting another basin to consolidate power.
# - An Earth Earth-Moon conference reveals a long-hidden treaty that binds or restricts lunar autonomy; multiple factions must navigate competing interests.
# - A meteor burst damages a sector’s energy grid; a team must improvise a repair using a space-age patch that could redefine lunar architecture.
# - A lunar festival reveals an ancient artifact discovered in a regolith layer, sparking disputes over ownership and the future of lunar science.
#
# If you want, tell me your preferred flavor (gritty cyberpunk, hopeful utopia, political thriller, etc.), the tone you aim for, and how big you want the city to be. I can tailor this concept into a ready-to-use setting with a map description, character roles, specific institutions, and plot hooks.

# %%
system_prompt = "You are a Science Fiction writer. Create a capital city at the users request"

scifi_agent = create_agent(model="gpt-5-nano",
                          system_prompt = system_prompt)

question = HumanMessage(content="What is the capital of Moon?")
response = scifi_agent.invoke(
            {"messages": [question]}
)

# %%
content = response['messages'][-1].content
if isinstance(content, list):
    content = "\n".join(str(x) for x in content)
print(content)
# Out:
# In this science-fiction setting, the capital of the Moon is Selene Prime.
#
# - Location: Perched on the rim of Shackleton Crater in the Moon’s southern polar region, chosen for near-constant solar exposure at the rim and access to water ice in the crater floors below. Earth hangs like a pale blue pendant in the sky.
#
# - Government: The Lunar Concord meets in Selene Prime, with a Parliamentary Council and a centralized Lumen Core that guides energy, science, and defense. It’s a federation city, balancing autonomous lunar settlements with Earth-led oversight.
#
# - Architecture and feel: A city of luminous basalt towers, crystalline domes, and shaded regolith gardens. A spine of light—the Lumen Path—runs along the crater rim, housing mag-lev transit and skybridges that connect districts. Public spaces glow softly at night using photonic panels harvested from the sun.
#
# - Notable districts:
#   - The Lumen Dome Quarter: government halls, courts, and the parliament chamber.
#   - The Crescent Market: trade, crafts, and lunar biotech startups.
#   - The Ice Core: water processing, fuel synthesis, and resource storage.
#   - The Archive of Eclipse: a vast library of lunar history and interstellar contact logs.
#   - The Quiet Slope: residential arcologies and artistic neighborhoods.
#
# - Economy: Helium-3 and solar fuels, water ice processing, advanced microgravity manufacturing, and a growing biotech sector that thrives in the moon’s low-gravity environment.
#
# - Culture: A fusion of utilitarian engineering mindset with luminous art. Public life emphasizes the "Light Code"—an ethos of transparency, efficiency, and shared duty to the colony.
#
# - Transportation: Skybridges and mag-lev pods along the rim, underground tunnels to surface access points, and high-tide lunar elevators that rise to orbital depots.
#
# - Vibe: A city that glows at the edge of day, turning the harshness of space into a confident, open society.
#
# If you’d like a different vibe for the capital—gritty frontier town, aristocratic lunar city-state, or a far-side fortress capital—I can tailor Selene Prime or propose a whole new name and backstory.

# %%
system_prompt = """
    You are a Science Fiction writer. Create a capital city at the users request"
    
    User: What is the capital of Mars?
    Scifi Writer: Marsialas

    User: What is the capital of Venus?
    Scifi Writer: Venusovia
                """
scifi_agent = create_agent(model="gpt-5-nano",
                          system_prompt = system_prompt)

question = HumanMessage(content="What is the capital of Moon?")
response = scifi_agent.invoke(
            {"messages": [question]}
)

# %%
pprint(response['messages'][-1].content)
# Out:
# 'Lunovia'

# %%
system_prompt = """
    You are a Science Fiction Writer. Please create a space capital city at the user's request.

    Please maintain the structure below:

    Name: The name of the capital city
    Location: Where it is based
    Vibe: 2-3 words describing the vibe of the space
    Economy: Main Industries
                """

scifi_agent = create_agent(model="gpt-5-nano",
                          system_prompt = system_prompt)

question = HumanMessage(content="What is the capital of Moon?")
response = scifi_agent.invoke(
            {"messages": [question]}
)

# %%
print(response["messages"][-1].content)
# Out:
# Name: Selene Prime
# Location: Shackleton Crater Rim, Moon's south polar region
# Vibe: crystal-polar metropolis
# Economy: Helium-3 mining; water-ice refinement; lunar manufacturing; orbital logistics; scientific tourism

# %%
from IPython.display import Markdown, display
display(Markdown(response["messages"][-1].content))
# Out:
# Name: Selene Prime
# Location: Shackleton Crater Rim, Moon's south polar region
# Vibe: crystal-polar metropolis
# Economy: Helium-3 mining; water-ice refinement; lunar manufacturing; orbital logistics; scientific tourism

# %%
from IPython.display import HTML, display
import html

text = response["messages"][-1].content
display(HTML(f"<pre>{html.escape(text)}</pre>"))
# Out:
# <pre>Name: Selene Prime
# Location: Shackleton Crater Rim, Moon&#x27;s south polar region
# Vibe: crystal-polar metropolis
# Economy: Helium-3 mining; water-ice refinement; lunar manufacturing; orbital logistics; scientific tourism</pre>

# %%
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

system_prompt = """
    You are a Science Fiction Writer. Please create a space capital city at the user's request.
                """

scifi_agent = create_agent(model="gpt-5-nano",
                          system_prompt = system_prompt,
                          response_format = CapitalInfo)

question = HumanMessage(content="What is the capital of Moon?")
response = scifi_agent.invoke(
            {"messages": [question]}
)

# %%
print(response["structured_response"])
print("Name: ",response["structured_response"].name)
print("Location: ", response["structured_response"].location)
print("Vibe: ", response["structured_response"].vibe)
print("Economy: ",response["structured_response"].economy)
# Out:
# name='Lunaris Prime' location='Shackleton Crater rim, lunar south polar region, ring of glass-domed districts connected by illuminated transit tunnels' vibe='crystal-minimalist metropolis bathed in Earthlight, buoyant in microgravity, a hub of science, culture, and commerce' economy='helium-3 mining, solar energy export, ISRU-based manufacturing, biotech research in microgravity, lunar tourism'
# Name:  Lunaris Prime
# Location:  Shackleton Crater rim, lunar south polar region, ring of glass-domed districts connected by illuminated transit tunnels
# Vibe:  crystal-minimalist metropolis bathed in Earthlight, buoyant in microgravity, a hub of science, culture, and commerce
# Economy:  helium-3 mining, solar energy export, ISRU-based manufacturing, biotech research in microgravity, lunar tourism
