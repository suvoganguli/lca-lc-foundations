# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# - Location: Built along the rim of Shackleton Crater in the south polar region, where long sunlight cycles feed solar farms and shielded habitats sit near water-ice deposits.
# - Government: The Lunar Directorate, a technocratic federation elected by district blocs, with a Council of Craters guiding policy and a Prime Administrator as head of state.
# - Architecture: A ring city carved into lunar regolith and reinforced with glassy alloys. Towers rise from a central spine, connected by solar-lattice domes that track the Sun. Interiors feature gravity-managed atria, hydroponic gardens, and subterranean reservoirs.
# - Daily life: A bustling, energy-rich metropolis where engineers, miners, and scientists mingle. Transit is mostly via heavy-rail lunar trains and vertical elevators; daylight planning schedules labor, recreation, and education around extended sunrise blocks.
# - Economy: Power export via solar-thermal networks, water-ice mining, and high-precision manufacturing for spacecraft components and life-support systems.
# - Landmarks and culture: The Helio Spire (a towering solar array hub and observatory), the Ice Gardens (glacier-lit parks), the Archive of Echoes (a public records temple carved into the crater rim). A cultural hallmark is the Dawn Accord festival, celebrating first light after long polar nights.
# - Etiquette and vibe: Pragmatic, with a strong esprit de corps among lunar workers; quiet, methodical conversation in public, with a shared ethos of sustainability and discovery.
#
# If you’d like, I can tailor Lunaris Prime to a different era (early colony, trade hub, or militarized capital), or rename it for a particular faction or culture.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.jpg', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.jpg', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon_city.jpg', 'type': 'image/jpeg', 'size': 185147, 'content': <memory at 0x12072ea40>, 'last_modified': datetime.datetime(2025, 12, 21, 10, 48, 16, 448000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/jpg"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The city in your image is Lunaspire, the capital of the Crescent Dominion. It sits on a vast, ice-veined continent at the southern edge of Nyxhaven, a world of perpetual twilight where the skies glow with auroras and two moons drift slowly overhead. Lunaspire is a political and cultural beacon, a place where ancient ritual meets cutting-edge technology.
#
# What Lunaspire feels like
# - A city of light and ice: spires carved from crystal-permeable ice and layered with bronze-gold filigree. The towers catch the auroras and toss the light outward in stained-glass rain.
# - A metropolis of mirrors: polished stones and glassy surfaces reflect moonlight in a thousand tiny suns, giving residents a sense of ever-present daylight even in the long polar nights.
# - A capital with a heartbeat: every quarter cycles its purpose—administrative, ceremonial, market, and scholarly—so the city feels like a living organism more than a static seat of power.
#
# Key features
# - Geography and layout: Lunaspire straddles a crescent-shaped ice plateau, with grand plazas at each bend of the crescent. A network of crystalline canals carries warm brine to keep streets navigable in winter and to power cooling/turbine stations in summer.
# - Architecture: towers taper to elegant spires, their exteriors embedded with warm-gold plates and living glass that shifts hue with the time of day. The tallest structure is the Council Spire, a multi-ringed tower that houses the Crescent Tribunal and the Archive of Echoes.
# - Materials and tech: working ice is reinforced with lattice-crystal skin. Photonic lattices harvest faint stellar light to heat and light the city. Antigrav sleds and floating pedestrian bridges weave between districts. The city also uses bioengineered lichen and algae to purify water and glow softly at night.
# - Government: Lunaspire is ruled by the Crescent Tribunal, a council of representatives from the major districts, guided by the Oracles of the Dawn—a small, clerical order that interprets celestial data and seasonal cycles. Decisions are preceded by public councils, but final authority rests with the Tribunal.
# - Society and culture: a culture of memory and ceremony. The people value the “twilights”—moments when day and night intersect—because they believe true insight comes at the edge of change. Music, poetry, and holographic storytelling are common in public squares.
# - Economy and trade: Lunaspire is a hub for frozen-tech, crystal optics, and bio-systems. Ice-wreaths (seasonal sculptures) are traded as currency-like tokens, while the Crescent Markets trade in rare minerals, memory-apps, and luminescent fabrics.
# - Language and education: two main tongues—a lyrical, ritual language used in ceremonies and a practical, scientific dialect for governance and industry. The university district trains engineers, astronomers, and archivists who study the Archive of Echoes.
# - Landmarks and districts:
#   - The Council Spire: governs the city, houses the Tribunal, and opens only on rare celestial events.
#   - The Archive of Echoes: a vast subterranean library of holographic records and living data-saplings that grow with use.
#   - The Crescent Market: a sprawling bazaar where merchants trade in ice-based art, crystal tools, and luminescent textiles.
#   - The Dawn Promenade: a wide, reflective avenue that winds around the city, lined with gardens of frost-adapted flora and reflective sculptures.
#   - The Observatory District: domed observatories and planetarium theatres that map Nyxhaven’s moons and suns.
# - Daily life: mornings begin with ritual tea brewed in vessels warmed by micro-waves, followed by public debates or storytelling in the plazas. Evenings are for music and light shows—projected constellations dance across the city’s ice-skin while vendors sell warm pastries and hot spiced milk.
# - Challenges and tensions: climate fluctuations can threaten ice stability; political factions push for greater decentralization versus a stronger central authority. The Archive sometimes reveals long-forgotten secrets that threaten established power, prompting political scheming.
# - History and myths: legend says Lunaspire rose from a fallen comet, and its spires are built atop one of Nyxhaven’s oldest frost-fields. The Moon’s “dimming” cycles are interpreted as omens, and yearly ceremonies honor the first light of spring and the last night of winter.
#
# Story seeds and hooks
# - A council election is sabotaged by a cryptic memory-swap—someone has erased a century of records, and the Archive must be healed by a memory-weaver.
# - A mysterious lunar anomaly causes the city’s photonic lattices to fail at dusk, plunging Lunaspire into a sudden, magical darkness that awakens old sea-creatures in the crystalline canals.
# - An envoy from a rival state arrives with a plea for alliance, but their technology requires a dangerous exchange: access to the Archive’s most intimate memories.
#
# Would you like me to tailor Lunaspire to a particular planet, culture, or era? Or focus on a specific district, character, or plot idea within Lunaspire?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.49it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# A furry friend with eyes so bright,
# Who prowls the night in soft moonlight.
# A gentle purr, a quiet song,
# In whiskered dreams she strolls along.
#
# Upon the windowsill she lays,
# And bathes in golden, warming rays.
# Her tail a dancer, swaying free,
# As graceful as the willow tree.
#
# With padded paws, she treads the floor,
# A silent hunter, evermore.
# Each playful leap, each bounding stride,
# Reveals the joy she cannot hide.
#
# A curious heart in feline form,
# She finds her comfort soft and warm.
# A cozy curl, a velvet nap,
# Beneath the sunlit day’s soft wrap.
#
# A loyal friend, both shy and bold,
# Her secrets in her eyes are told.
# With every meow or gentle stare,
# She shows her love beyond compare.
